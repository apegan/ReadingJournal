# %% [markdown]
# # Day 6 Reading Journal
#
# This journal includes several required exercises, but it is meant to encourage active reading more generally.  You should use the journal to take detailed notes, catalog questions, and explore the content from Think Python deeply.
#
# Reading: Think Python Chapter 5.8-5.14, 6.5-6.11
#
# **Due: Monday, February 6 at 12 noon**

# %% [markdown]
# ## [Chapter 5.8 - 5.14](http://www.greenteapress.com/thinkpython2/html/thinkpython2006.html)
#
# [Python Tutor](http://pythontutor.com/) can be helpful for visualizing stack diagrams, including for recursive execution.
#
# Chapter 5 leads into Chapter 6, and all the required exercises for this reading are in the Chapter 6 section.

# %% [markdown]
# A function that calls itself is recursive, the process of executing it is called recursium.
#
# Example function:
# def countdown(n):
#     if n <= 0:
#         print('Blastoff!')
#     else:
#         print(n)
#         countdown(n-1)
#
#
# A return statement exits the function, and the remaining lines don't run

# %% [markdown]
# Stack Diagram for print_n called with s = 'Hello' and n=2
# for def print_n(s, n):
#     if n <= 0:
#         return
#     print(s)
#     print_n(s, n-1)
#
# print_n('Hello', 2)
#
# __main__
# print_n     n --> 2     'Hello'
# print_n     n --> 1     'Hello'
# print_n     n --> 0

# %% [markdown]
# Write a function called do_n that takes a function object and a number, n, as arguments, and that calls the given function n times.
#
# def do_n(action, n):
#     if n<= 0:
#         return
#     do_n(action, n-1)

# %% [markdown]
# Infinite recursion looks like this.
# def recurse():
#     recurse()
#
# Best not to do this.

# %% [markdown]
# Input : stops the program and waits for the user to type something
#
#     text = input ('What is your name?\n')
#
# Newline: causes a line break
#     \n
#
# Integer Input: convert the return value to integer
#     int(input('What is your age?'))

# %% [markdown]
# Fruitful function: Calling one function from within the body of another, or using the return value of one function as an argument to the call of another. A function that yields a return value instead of None.
#
# In a fruitful function, it is a good idea to ensure that every possible path through the program hits a return statement.
#
#
# Incremental development: the goal of incremental development is to avoid long debugging sessions by adding and testing only a small amount of code at a time.
#
# Ex:
# def distance(x1, y1, x2, y2):
#     return 0.0
#
#     then...
#
# def distance(x1, y1, x2, y2):
#     dx = x2 - x1
#     dy = y2 - y1
#     print('dx is', dx)
#     print('dy is', dy)
#     return 0.0
#
#     then...
#
# def distance(x1, y1, x2, y2):
#     dx = x2 - x1
#     dy = y2 - y1
#     dsquared = dx**2 + dy**2
#     print('dsquared is: ', dsquared)
#     return 0.0
#
#     then...
#
# def distance(x1, y1, x2, y2):
#     dx = x2 - x1
#     dy = y2 - y1
#     dsquared = dx**2 + dy**2
#     result = math.sqrt(dsquared)
#     return result
#
# Should delete all print statements used for debugging once the code is working.
#
# Composition
# from this...
#     def circle_area(xc, yc, xp, yp):
#     radius = distance(xc, yc, xp, yp)
#     result = area(radius)
#     return result
#
# to this...
#     def circle_area(xc, yc, xp, yp):
#     return area(distance(xc, yc, xp, yp))
#
# Booleans
# just write this...
#     if is_divisible(x, y):
#     print('x is divisible by y')
#
# this is not necessary
#     if is_divisible(x, y) == True:
#     print('x is divisible by y')
#
# Recursion
#     Trust that it works, no need to follow it every time
#     def factorial(n):
#     if n == 0:
#         return 1
#     else:
#         recurse = factorial(n-1)
#         result = n * recurse
#         return result
#
#  Factorial function that checks if input is integer and nonnegative
#
#  def factorial(n):
#     if not isinstance(n, int):
#         print('Factorial is only defined for integers.')
#         return None
#     elif n < 0:
#         print('Factorial is not defined for negative integers.')
#         return None
#     elif n == 0:
#         return 1
#     else:
#         return n * factorial(n-1)

# %% [markdown]
# ## [Chapter 6.5 - 6.11](http://www.greenteapress.com/thinkpython2/html/thinkpython2007.html)

# %% [markdown]
# Debugging
# Three possibilities for debugging
#
#     1) There is something wrong with the arguments the function is getting; a precondition is violated.
#     solution: print values of the parameters and types
#     solution: write code to check preconditions, e.g. guardian code
#
#     2) There is something wrong with the function; a postcondition is violated.
#     solution: add a print statement before each return statement
#
#     3) There is something wrong with the return value or the way it is being used.
#     solution: print return value
#     solution: check the result by hand
#     solution: consider calling the function with values that make it easy to check the result
#     solution: make sure the return value is being used correctly
#
#
# Note: you can use spaces to control the indentation of your print statement
#      space = ' ' * (4 * n)
#      print(space, 'factorial', n)

# %% [markdown]
# ### Exercise 6.1
#
# Draw a stack diagram for the following program. What does the program print?
#
# You can do this on paper or using [Python Tutor](http://pythontutor.com/)

# %%
def b(z):
    prod = a(z, z)
    print(z, prod)
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print(c(x, y+3, x+y))

# %% [markdown]
# Used the Python Tutor

# %% [markdown]
# Notes:
#     strings are immutable (characters in a string cannot be modified, Assignments to elements or slices of immutable types cause a runtime error.)
#     lists are mutable (elements of a list can be modified)
#     tuples are immutable (tuple is a sequence of items of any type)
#
#
# Base case
#     A branch of the conditional statement in a recursive function that does not result in a recursive call

# %% [markdown]
# ### Exercise 6.3
#
# A palindrome is a word that is spelled the same backward and forward, like “noon” and “redivider”. Recursively, a word is a palindrome if the first and last letters are the same and the middle is a palindrome.
#
# You can use the `first`, `last`, and `middle` helper functions defined in Think Python, or do the string slices inside your function directly. Be sure to think about your base cases.
#
# Write a function called `is_palindrome` that takes a string argument and returns `True` if it is a palindrome and `False` otherwise. Remember that you can use the built-in function `len` to check the length of a string.
#
# Write some unit tests for your function (optionally using doctest) to show that it works as intended.

# %%
'''
base case in the very beginning
base cases 
    "if not" checks for empty string, any falsey value, empty, zero, none, for false
    first letter is the same as the last letter
recursive
    the middle function to take the stuff between the first and last letter
    check if the first and last are equal
    if yes, then start again
    >>> is_palindrome('racecar')
    True
    >>> is_palindrome('drones')
    False
'''


def is_palindrome(s):
    if s == "":
        print(s)
        return True
    if not isinstance(s, str):
        print('Needs to be a string.')
        return None
    elif s[0] != s[-1]:
        return False
    elif s[0] == s[-1]:
        s = s[1: len(s)-1]
        return is_palindrome(s)

        
is_palindrome('boob')
# Out:
# True

# %% [markdown]
# ### Challenge (optional)
#
# Use the word list from [Chapter 9.1](http://www.greenteapress.com/thinkpython2/html/thinkpython2010.html) Exercise 1 to find all of the palindromes.

# %%
fin = open('words.txt')

for line in fin:
    word = line.strip()
    palindrome = is_palindrome(word)
    if palindrome == True:
        print(word)
# Out:
# aa
#
# aba
#
# aga
#
# aha
#
# ala
#
# alula
#
# ama
#
# ana
#
# anna
#
# ava
#
# awa
#
# bib
#
# bob
#
# boob
#
# bub
#
# civic
#
# dad
#
# deed
#
# deified
#
# deked
#
# deled
#
# denned
#
# dewed
#
# did
#
# dud
#
# eke
#
# eme
#
# ere
#
# eve
#
# ewe
#
# eye
#
# gag
#
# gig
#
# hah
#
# halalah
#
# hallah
#
# huh
#
# kaiak
#
# kayak
#
# keek
#
# kook
#
# level
#
# madam
#
# marram
#
# mem
#
# mim
#
# minim
#
# mom
#
# mum
#
# noon
#
# nun
#
# oho
#
# otto
#
# pap
#
# peep
#
# pep
#
# pip
#
# poop
#
# pop
#
# pup
#
# radar
#
# redder
#
# refer
#
# reifier
#
# repaper
#
# reviver
#
# rotator
#
# rotor
#
# sagas
#
# sees
#
# selles
#
# sememes
#
# semes
#
# seres
#
# sexes
#
# shahs
#
# sis
#
# solos
#
# sos
#
# stets
#
# tat
#
# tenet
#
# terret
#
# tit
#
# toot
#
# tot
#
# tut
#
# vav
#
# waw
#
# wow
#
# yay

# %%
fin = open('words.txt')

def cats(line):
    word = line.strip()
    palindrome = is_palindrome(word)
    if palindrome == True:
        return word

for line in fin:
    print(cats(line))
# Out:
# aa
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
#
# aba
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
fin = open('words.txt')

[cats(line) for line in fin if cats(line) is not None]
# Out:
# ['aa',
#  'aba',
#  'aga',
#  'aha',
#  'ala',
#  'alula',
#  'ama',
#  'ana',
#  'anna',
#  'ava',
#  'awa',
#  'bib',
#  'bob',
#  'boob',
#  'bub',
#  'civic',
#  'dad',
#  'deed',
#  'deified',
#  'deked',
#  'deled',
#  'denned',
#  'dewed',
#  'did',
#  'dud',
#  'eke',
#  'eme',
#  'ere',
#  'eve',
#  'ewe',
#  'eye',
#  'gag',
#  'gig',
#  'hah',
#  'halalah',
#  'hallah',
#  'huh',
#  'kaiak',
#  'kayak',
#  'keek',
#  'kook',
#  'level',
#  'madam',
#  'marram',
#  'mem',
#  'mim',
#  'minim',
#  'mom',
#  'mum',
#  'noon',
#  'nun',
#  'oho',
#  'otto',
#  'pap',
#  'peep',
#  'pep',
#  'pip',
#  'poop',
#  'pop',
#  'pup',
#  'radar',
#  'redder',
#  'refer',
#  'reifier',
#  'repaper',
#  'reviver',
#  'rotator',
#  'rotor',
#  'sagas',
#  'sees',
#  'selles',
#  'sememes',
#  'semes',
#  'seres',
#  'sexes',
#  'shahs',
#  'sis',
#  'solos',
#  'sos',
#  'stets',
#  'tat',
#  'tenet',
#  'terret',
#  'tit',
#  'toot',
#  'tot',
#  'tut',
#  'vav',
#  'waw',
#  'wow',
# ...

# %% [markdown]
# ### Exercise 6.4
#
# A number `a` is a power of `b` if it is divisible by `b` and `a/b` is a power of `b`. Write a function called `is_power` that takes parameters `a` and `b` and returns `True` if `a` is a power of `b`. Note: you will have to think about the base case.

# %%
def is_power(a,b):
    if(a%b != 0):
        return False
    elif(a/b == 1):
        return True
    else:
        return is_power(a/b,b)
    
    
is_power(8,2)

is_power(90,4)
# Out:
# False

# %% [markdown]
# ### Challenge (optional) - Exercise 6.5
#
# The greatest common divisor (GCD) of `a` and `b` is the largest number that divides both of them with no remainder.
#
# One way to find the GCD of two numbers is based on the observation that if `r` is the remainder when `a` is divided by `b`, then `gcd(a, b) = gcd(b, r)`. As a base case, we can use `gcd(a, 0) = a`.
#
# Write a function called `gcd` that takes parameters `a` and `b` and returns their greatest common divisor.

# %% [markdown]
# ## Reading Journal feedback
#
# [Please complete this short survey](https://docs.google.com/forms/d/e/1FAIpQLScQekhUrf6YYjpfQiAAbavLIA-IJklv_PX1BWbGgxj7JPolmw/viewform?c=0&w=1)
#
# If you have any comments on this Reading Journal, feel free to leave them in the survey linked above. This could include suggestions to improve the exercises, topics you'd like to see covered in class next time, or other feedback.
#
# If you have Python questions or run into problems while completing the reading, you should post them to Piazza instead so you can get a quick response before your journal is submitted.
